# %% [markdown]
# # Understanding the files

# %%
#importing libraries
import pandas as pd
from datetime import datetime

# %%
df_timesheets = pd.read_csv('timesheets.csv', sep="|")

df_timesheets.head()
# Out:
#    clock_off_date_time   clock_on_date_time  cost_per_hour   fname    lname  \
# 0  2017-05-01 14:50:03  2017-05-01 10:09:47            300  Adrian    Giles
# 1  2017-05-23 15:43:54  2017-05-23 12:00:53            300  George  Howells
# 2  2017-08-14 10:20:23  2017-08-14 10:18:53            200     Jay    Evans
# 3  2017-02-23 12:46:30  2017-02-23 10:11:21            300   Shaun  O'Neill
# 4  2017-05-04 16:38:50  2017-05-04 15:49:58            100  Pamela    Price
#
#    person_id
# 0  ZZ134689T
# 1  ZZ699213T
# 2  ZZ186312T
# 3  ZZ285185T
# 4  ZZ322544T

# %%
df_equip_lu = pd.read_csv('equipment_lu.csv', sep="|")

df_equip_lu.head()
# Out:
#            eq_id      model
# 0  0-698-58325-6    BOT-001
# 1  1-81657-661-1    BOT-001
# 2  0-236-67768-3       BTl9
# 3            NaN       BTl9
# 4  1-108-16741-1  BOT-001v2

# %%
import json
file = open('machine_transaction.json')
data = json.load(file)
file.close()
data
# Out:
# [{'eq_id': '0-341-31995-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '25'},
#   'operator': 'jgeorg473',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '36'},
#   'operator': 'jpeter263',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'gholde135',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '14'},
#   'operator': 'ghardy464',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7570-5849-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '33'},
#   'operator': 'gholde135',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7570-5849-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '30'},
#   'operator': 'srober504',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '14'},
#   'operator': 'cdavis241',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'hjenki751',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'awebst460',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-325-37497-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '22'},
#   'operator': 'awebst460',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '23'},
#   'operator': 'madams054',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '40'},
#   'operator': 'madams054',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7110-4249-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '18'},
#   'operator': 'rshaw248',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '18'},
#   'operator': 'sellis090',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-81657-661-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '39'},
#   'operator': 'jgeorg473',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '11'},
#   'operator': 'mnewto978',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'thowel463',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '10'},
#   'operator': 'dstoke916',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'cdavis241',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-82442-846-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '22'},
#   'operator': 'plee963',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '28'},
#   'operator': 'srober504',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-904698-44-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'hjenki751',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '17'},
#   'operator': 'mnewto978',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '15'},
#   'operator': 'thunt444',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-659-12918-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'mnewto978',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'mholme172',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-8126-9848-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '40'},
#   'operator': 'ebarbe158',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'ghardy464',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-698-58325-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '26'},
#   'operator': 'ckaur550',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-82005-051-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '25'},
#   'operator': 'ghardy464',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '34'},
#   'operator': 'nnicho636',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'madams054',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'thowel463',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '11'},
#   'operator': 'sward904',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '18'},
#   'operator': 'jgeorg473',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'srober504',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '11'},
#   'operator': 'ebarbe158',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7055-6975-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '32'},
#   'operator': 'cdavis241',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'madams054',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '22'},
#   'operator': 'cwood121',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'sellis090',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7110-4249-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'ckaur550',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-82005-051-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'sward904',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '15'},
#   'operator': 'cwood121',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '25'},
#   'operator': 'cclark989',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '36'},
#   'operator': 'hjenki751',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-913574-46-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '29'},
#   'operator': 'hjenki751',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '10'},
#   'operator': 'dstoke916',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '35'},
#   'operator': 'gberry071',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-447-00362-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '27'},
#   'operator': 'mholme172',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-18-365356-4',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '14'},
#   'operator': 'mholme172',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'lhamil584',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '34'},
#   'operator': 'thowel463',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-81657-661-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '33'},
#   'operator': 'jgeorg473',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-09-267078-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '20'},
#   'operator': 'mholme172',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '38'},
#   'operator': 'cclark989',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-153-45182-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '20'},
#   'operator': 'awebst460',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-659-12918-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '15'},
#   'operator': 'jgeorg473',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'aricha693',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '25'},
#   'operator': 'awebst460',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '35'},
#   'operator': 'nnicho636',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '0-8126-9848-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'dtomli922',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '17'},
#   'operator': 'mholme172',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '28'},
#   'operator': 'awebst460',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '18'},
#   'operator': 'madams054',
#   'transaction_date': '01.01.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '33'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-447-00362-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '29'},
#   'operator': 'mkelly035',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '39'},
#   'operator': 'jcarte318',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '15'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '27'},
#   'operator': 'tosbor549',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '35'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '11'},
#   'operator': 'aricha693',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'cnicho763',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-68565-420-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '37'},
#   'operator': 'jdavie421',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-7070-9686-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '25'},
#   'operator': 'srose554',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-299-91054-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '33'},
#   'operator': 'ddavey930',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-589-97501-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '27'},
#   'operator': 'jdean099',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '36'},
#   'operator': 'jfletc776',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-7570-5849-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '22'},
#   'operator': 'cander719',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-299-91054-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '16'},
#   'operator': 'nbaker303',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '20'},
#   'operator': 'fbarne021',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'aedwar721',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '23'},
#   'operator': 'aedwar721',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '14'},
#   'operator': 'cander719',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '14'},
#   'operator': 'cwrigh038',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '38'},
#   'operator': 'jdavie421',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '18'},
#   'operator': 'jdavie421',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '12'},
#   'operator': 'tosbor549',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '21'},
#   'operator': 'cander719',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-393-84813-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '35'},
#   'operator': 'aedwar721',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-100-62167-9',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '17'},
#   'operator': 'ldavis353',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '29'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-284-46991-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '27'},
#   'operator': 'jdean099',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-10-966375-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '13'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '24'},
#   'operator': 'bnolan148',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '16'},
#   'operator': 'aedwar721',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-323-50723-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'aedwar721',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-7055-6975-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'jdavie421',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '10'},
#   'operator': 'aricha693',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-913574-46-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'cthomp510',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '12'},
#   'operator': 'mkelly035',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '28'},
#   'operator': 'cnicho763',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-5479-4382-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'cwrigh038',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '22'},
#   'operator': 'cthomp510',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-393-84813-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '27'},
#   'operator': 'mkelly035',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '36'},
#   'operator': 'pevans517',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '11'},
#   'operator': 'pevans517',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'cander719',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '40'},
#   'operator': 'jdavie421',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-393-84813-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '26'},
#   'operator': 'jcarte318',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-180-46921-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '26'},
#   'operator': 'jdean099',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-252-27751-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'ddavey930',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '29'},
#   'operator': 'srose554',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-05-312034-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'nbaker303',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.02.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '36'},
#   'operator': 'trose403',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-341-31995-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'kyoung891',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-82442-846-4',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '31'},
#   'operator': 'smanni347',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '35'},
#   'operator': 'ldean945',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '29'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'skenne975',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-7070-9686-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '26'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-69369-100-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '11'},
#   'operator': 'trose403',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '17'},
#   'operator': 'akaur188',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-7110-4249-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'mdavis270',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'kbarbe604',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '19'},
#   'operator': 'ajenni468',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-82005-051-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '21'},
#   'operator': 'jobri292',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '29'},
#   'operator': 'cwilki169',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-01-055431-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '21'},
#   'operator': 'akaur188',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '10'},
#   'operator': 'dgarne905',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-913574-46-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '10'},
#   'operator': 'jobri292',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '36'},
#   'operator': 'jobri292',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '35'},
#   'operator': 'dreeve605',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-79059-259-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '33'},
#   'operator': 'omason274',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '16'},
#   'operator': 'vwebb416',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '18'},
#   'operator': 'rfrase490',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '31'},
#   'operator': 'kbarbe604',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'rfrase490',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-82005-051-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '18'},
#   'operator': 'smanni347',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-18-365356-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '36'},
#   'operator': 'skenne975',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-8126-9848-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '10'},
#   'operator': 'dgarne905',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-589-97501-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '23'},
#   'operator': 'rfrase490',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'omason274',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '20'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '27'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'kbarbe604',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '34'},
#   'operator': 'asutto514',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-7570-5849-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '16'},
#   'operator': 'dreeve605',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '30'},
#   'operator': 'thyde826',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '25'},
#   'operator': 'dnorto138',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '10'},
#   'operator': 'kdicki101',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '22'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-299-91054-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '32'},
#   'operator': 'kdicki101',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-393-84813-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '24'},
#   'operator': 'dgarne905',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-03-739685-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'cwilki169',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '39'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'omason274',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-03-739685-4',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '26'},
#   'operator': 'omason274',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'ldean945',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'jobri292',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-82625-416-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '36'},
#   'operator': 'dgarne905',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-904698-44-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '11'},
#   'operator': 'dreeve605',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-153-45182-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '18'},
#   'operator': 'skenne975',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '19'},
#   'operator': 'mdavis270',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-299-91054-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '36'},
#   'operator': 'cwilki169',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-189-21228-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '34'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-09-267078-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '36'},
#   'operator': 'kbarbe604',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-89198-495-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '30'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-238-64509-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '25'},
#   'operator': 'cwilki169',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-659-12918-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '38'},
#   'operator': 'akaur188',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68565-420-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '27'},
#   'operator': 'rfrase490',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-82625-416-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '11'},
#   'operator': 'dnorto138',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-01-055431-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '12'},
#   'operator': 'trose403',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '34'},
#   'operator': 'ajenni468',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '34'},
#   'operator': 'vwebb416',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-323-50723-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '20'},
#   'operator': 'cwilki169',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '22'},
#   'operator': 'awilki829',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '32'},
#   'operator': 'thyde826',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '32'},
#   'operator': 'eprice699',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '25'},
#   'operator': 'kdicki101',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '25'},
#   'operator': 'dnorto138',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-325-37497-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '26'},
#   'operator': 'awilki829',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '31'},
#   'operator': 'prees756',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '37'},
#   'operator': 'jobri292',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '11'},
#   'operator': 'prees756',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '29'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '32'},
#   'operator': 'kyoung891',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '23'},
#   'operator': 'skenne975',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-57577-480-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '13'},
#   'operator': 'asutto514',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-252-27751-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '40'},
#   'operator': 'ajenni468',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-57577-480-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '31'},
#   'operator': 'jhudso812',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-913574-46-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '10'},
#   'operator': 'trose403',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-7070-9686-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'trose403',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-341-31995-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'dharve288',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '22'},
#   'operator': 'ldean945',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '0-904698-44-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'mdavis270',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-180-46921-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '40'},
#   'operator': 'kbarbe604',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '23'},
#   'operator': 'dnorto138',
#   'transaction_date': '01.03.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '18'},
#   'operator': 'smanni347',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '34'},
#   'operator': 'dhowe899',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-17-435611-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '33'},
#   'operator': 'across796',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '22'},
#   'operator': 'ecole549',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-422-76098-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'ecole549',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '15'},
#   'operator': 'cpatel983',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '19'},
#   'operator': 'cmurra221',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-108-16741-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '23'},
#   'operator': 'dhowe899',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-180-46921-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '23'},
#   'operator': 'cbutle065',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '17'},
#   'operator': 'gkelly181',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-455-54621-5',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '23'},
#   'operator': 'wkhan675',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'cpatel983',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'cbrown635',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-8126-9848-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '18'},
#   'operator': 'scurti695',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-68565-420-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '28'},
#   'operator': 'espenc822',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82625-416-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '37'},
#   'operator': 'smanni347',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-17-435611-0',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '35'},
#   'operator': 'cmurra221',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '36'},
#   'operator': 'dhowe899',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '17'},
#   'operator': 'blamb205',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '28'},
#   'operator': 'rlambe948',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-913574-46-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '30'},
#   'operator': 'sjohns098',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-341-31995-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '29'},
#   'operator': 'smanni347',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-00-978897-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'cpatel983',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82005-051-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '35'},
#   'operator': 'across796',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'cmurra221',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '32'},
#   'operator': 'espenc822',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '11'},
#   'operator': 'rlambe948',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '30'},
#   'operator': 'cpatel983',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-5479-4382-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '21'},
#   'operator': 'ghawki242',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-81657-661-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '33'},
#   'operator': 'wkhan675',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '38'},
#   'operator': 'blamb205',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-68164-517-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '31'},
#   'operator': 'dhowe899',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-659-12918-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '16'},
#   'operator': 'dreeve605',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '10'},
#   'operator': 'sjohns098',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'dreeve605',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-17-435611-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '39'},
#   'operator': 'rlambe948',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '34'},
#   'operator': 'espenc822',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '1-69369-100-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '32'},
#   'operator': 'gkelly181',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'aandre910',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-7804-2562-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '24'},
#   'operator': 'ecole549',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '17'},
#   'operator': 'ataylo410',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-03-739685-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '33'},
#   'operator': 'across796',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'sjohns098',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-455-54621-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '26'},
#   'operator': 'ldavis353',
#   'transaction_date': '01.04.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '29'},
#   'operator': 'rsmith703',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'gpearc911',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-659-12918-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '33'},
#   'operator': 'jsteph094',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-00-978897-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '31'},
#   'operator': 'abull247',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-68565-420-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'cprice677',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'ascott183',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-03-739685-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '15'},
#   'operator': 'vsteve821',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'jbrown164',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-100-62167-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'jevans342',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-7055-6975-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '26'},
#   'operator': 'hbenne529',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '12'},
#   'operator': 'vsteve821',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-447-00362-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'ascott183',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '11'},
#   'operator': 'rsmith703',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-189-21228-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '37'},
#   'operator': 'mbarlo036',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-7110-4249-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '30'},
#   'operator': 'jevans342',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '34'},
#   'operator': 'kmarsh507',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-04-759562-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '15'},
#   'operator': 'fparke063',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-82233-397-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '20'},
#   'operator': 'jevans009',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-89198-495-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '38'},
#   'operator': 'kmarsh507',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '13'},
#   'operator': 'cmccar896',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-69369-100-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'jsteph094',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '22'},
#   'operator': 'ipowel780',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-10-966375-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'jevans009',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-108-16741-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'ascott183',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-68565-420-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '34'},
#   'operator': 'abull247',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'hpatel151',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'gpearc911',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-8126-9848-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '11'},
#   'operator': 'vsteve821',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '28'},
#   'operator': 'ageorg930',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'jsteph094',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'ibrown428',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '21'},
#   'operator': 'vsteve821',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-57577-480-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'abull247',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '25'},
#   'operator': 'mbarlo036',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-424-27866-9',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '28'},
#   'operator': 'ageorg930',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-527-63722-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '29'},
#   'operator': 'ascott183',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-284-46991-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'jsteph094',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '39'},
#   'operator': 'aprest195',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-589-97501-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '24'},
#   'operator': 'aprest195',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-69369-100-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '36'},
#   'operator': 'mbarlo036',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '12'},
#   'operator': 'ibrown428',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-341-31995-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '25'},
#   'operator': 'jsteph094',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '28'},
#   'operator': 'jevans342',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '40'},
#   'operator': 'ipowel780',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-7570-5849-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '18'},
#   'operator': 'hbenne529',
#   'transaction_date': '01.05.2017'},
#  {'eq_id': '0-593-62587-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'cmccar896',
#   'transaction_date': '01.05.2017'},
# ...
#  {'eq_id': '1-5479-4382-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '29'},
#   'operator': 'pjones978',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-7070-9686-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'dharve288',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '35'},
#   'operator': 'ljones390',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-17-435611-0',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '30'},
#   'operator': 'fbrown903',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-01-055431-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '15'},
#   'operator': 'ahudso750',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-904698-44-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'vsmith833',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '33'},
#   'operator': 'cgill317',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'vsmith833',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-236-67768-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'csaund914',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-05-312034-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '39'},
#   'operator': 'kwatso092',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '36'},
#   'operator': 'across796',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-82625-416-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '33'},
#   'operator': 'fbrown903',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '30'},
#   'operator': 'cgill317',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-325-37497-X',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '20'},
#   'operator': 'ljones390',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-189-21228-5',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '38'},
#   'operator': 'awatts494',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-7742-3975-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'kkhan108',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-9776520-8-4',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '17'},
#   'operator': 'kkhan108',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'vsmith833',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-75070-515-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '15'},
#   'operator': 'fbrown903',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '40'},
#   'operator': 'pjones978',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-135-44160-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '30'},
#   'operator': 'pcook103',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-10-966375-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '11'},
#   'operator': 'mthomp618',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-367-69357-7',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'gadams740',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-153-45182-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '30'},
#   'operator': 'pmoss037',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-17-435611-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'nbaker303',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-100-62167-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '28'},
#   'operator': 'pmoss037',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '30'},
#   'operator': 'ljones390',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-10-966375-6',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '35'},
#   'operator': 'kwatso092',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '0-7055-6975-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '26'},
#   'operator': 'vgreen014',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '12'},
#   'operator': 'thyde826',
#   'transaction_date': '01.15.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '30'},
#   'operator': 'eburke794',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'eburke794',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-238-64509-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '31'},
#   'operator': 'rfrase141',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-68049-926-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '37'},
#   'operator': 'mstanl951',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '13'},
#   'operator': 'kwatts481',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-490-60642-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'kwatts481',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-490-60642-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '15'},
#   'operator': 'lwilli564',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-09-175680-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'bwood898',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-4141-7434-9',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'bwood898',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '12'},
#   'operator': 'mholme172',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-323-50723-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '34'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-05-211877-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '23'},
#   'operator': 'lwilli564',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-05-312034-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-189-21228-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '24'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-00-978897-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '25'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '27'},
#   'operator': 'astone383',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-922557-26-9',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '31'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '33'},
#   'operator': 'pbowen184',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-925366-36-7',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '25'},
#   'operator': 'lwilli564',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-81657-661-1',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '28'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-7804-2562-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '14'},
#   'operator': 'astone383',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-10-966375-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '21'},
#   'operator': 'eholme495',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-136-78176-5',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '16'},
#   'operator': 'mholme172',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-284-46991-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '13'},
#   'operator': 'eburke794',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '31'},
#   'operator': 'rhaywa271',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '28'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-189-21228-5',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '19'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-9655297-1-1',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '27'},
#   'operator': 'astone383',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '33'},
#   'operator': 'lwilli564',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-698-58325-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '19'},
#   'operator': 'mstanl951',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '27'},
#   'operator': 'asande260',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-18-365356-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'kwatts481',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-09-267078-4',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '26'},
#   'operator': 'pjohns306',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '18'},
#   'operator': 'bwood898',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-589-97501-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '16'},
#   'operator': 'jward069',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-82442-846-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'eburke794',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-01-055431-X',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '22'},
#   'operator': 'jandre706',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-7391782-4-6',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '38'},
#   'operator': 'jandre706',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-551-70009-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '34'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-341-31995-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '32'},
#   'operator': 'astone383',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '34'},
#   'operator': 'pjohns306',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '35'},
#   'operator': 'eholme495',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-153-45182-4',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '10'},
#   'operator': 'rhaywa271',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '14'},
#   'operator': 'elee937',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-85198-360-X',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '39'},
#   'operator': 'pbowen184',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '16'},
#   'operator': 'elee937',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-153-45182-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '33'},
#   'operator': 'jhart666',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-82442-846-4',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'rhaywa271',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '23'},
#   'operator': 'dskinn007',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '0-904698-44-0',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '35'},
#   'operator': 'jward069',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-100-62167-9',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '35'},
#   'operator': 'drhode344',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-130-92790-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '26'},
#   'operator': 'kwatts481',
#   'transaction_date': '01.16.2017'},
#  {'eq_id': '1-874484-95-3',
#   'operation': {'activity': 'painting', 'unit': 'ml', 'volume': '35'},
#   'operator': 'asande260',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-04-833845-2',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '17'},
#   'operator': 'apatel163',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-57577-480-1',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '11'},
#   'operator': 'apatel163',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-928644-69-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '38'},
#   'operator': 'smello891',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-165-91623-1',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '11'},
#   'operator': 'jcoope992',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-551-70009-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'kricha293',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-02-051164-8',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '16'},
#   'operator': 'cdavis241',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-7804-2562-6',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '32'},
#   'operator': 'gwhite263',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-483-86369-6',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '37'},
#   'operator': 'dward855',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-682-18222-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '28'},
#   'operator': 'dward855',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-551-70009-2',
#   'operation': {'activity': 'formulation', 'unit': 'ml', 'volume': '16'},
#   'operator': 'gkent691',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '0-530-29587-3',
#   'operation': {'activity': '3d_printing', 'unit': 'kg', 'volume': '28'},
#   'operator': 'dwood529',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-69369-100-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '28'},
#   'operator': 'kleach401',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-942462-98-0',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '35'},
#   'operator': 'gpearc911',
#   'transaction_date': '01.17.2017'},
#  {'eq_id': '1-393-84813-3',
#   'operation': {'activity': 'carbonizing', 'unit': 'g', 'volume': '29'},
#   'operator': 'apatel163',
#   'transaction_date': '01.17.2017'},
#  ...]

# %%
df_mach_tran = pd.read_json('machine_transaction.json')
df_mach_tran.head()
# Out:
#            eq_id                                          operation  \
# 0  0-341-31995-3  {'activity': '3d_printing', 'unit': 'kg', 'vol...
# 1  1-874484-95-3  {'activity': 'formulation', 'unit': 'ml', 'vol...
# 2  1-130-92790-3  {'activity': 'carbonizing', 'unit': 'g', 'volu...
# 3  1-79059-259-3  {'activity': 'painting', 'unit': 'ml', 'volume...
# 4  0-7570-5849-3  {'activity': '3d_printing', 'unit': 'kg', 'vol...
#
#     operator transaction_date
# 0  jgeorg473       01.01.2017
# 1  jpeter263       01.01.2017
# 2  gholde135       01.01.2017
# 3  ghardy464       01.01.2017
# 4  gholde135       01.01.2017

# %% [markdown]
# # Data quality check

# %% [markdown]
# #### Timesheets file

# %%
#testing null values
df_timesheets.isnull().sum()
# Out:
# clock_off_date_time    0
# clock_on_date_time     0
# cost_per_hour          0
# fname                  0
# lname                  0
# person_id              0
# dtype: int64

# %%
#data types
df_timesheets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# clock_off_date_time    10000 non-null object
# clock_on_date_time     10000 non-null object
# cost_per_hour          10000 non-null int64
# fname                  10000 non-null object
# lname                  10000 non-null object
# person_id              10000 non-null object
# dtypes: int64(1), object(5)
# memory usage: 468.8+ KB

# %%
#changing datetime columns to datetime objects

df_timesheets.clock_off_date_time = df_timesheets.clock_off_date_time.apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
df_timesheets.clock_on_date_time = df_timesheets.clock_on_date_time.apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# checking if the changes were done
df_timesheets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# clock_off_date_time    10000 non-null datetime64[ns]
# clock_on_date_time     10000 non-null datetime64[ns]
# cost_per_hour          10000 non-null int64
# fname                  10000 non-null object
# lname                  10000 non-null object
# person_id              10000 non-null object
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 468.8+ KB

# %% [markdown]
# #### Equipment_lu file

# %%
df_equip_lu.isnull().sum()
# Out:
# eq_id    11
# model     0
# dtype: int64

# %%
df_equip_lu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 2 columns):
# eq_id    69 non-null object
# model    80 non-null object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
#since eq_id as a joinable field, we must avoid null values

pd.set_option('display.max.rows', 100)

df_equip_lu.groupby('eq_id')['model'].value_counts()
# Out:
# eq_id          model
# 0-03-739685-4  A324404                   1
# 0-04-759562-0  BTl9                      1
# 0-05-211877-0  PJ-909                    1
# 0-05-312034-5  AM-953                    1
# 0-09-267078-4  C794645                   1
# 0-10-966375-6  CP-144                    1
# 0-17-435611-0  AM-953                    1
# 0-236-67768-3  BTl9                      1
# 0-252-27751-1  BOT-301                   1
# 0-299-91054-7  CP-144                    1
# 0-325-37497-X  YS-BB74                   1
# 0-367-69357-7  AM-953                    1
# 0-422-76098-6  BOT-001                   1
# 0-424-27866-9  BOT-301                   1
# 0-447-00362-3  A324404                   1
# 0-455-54621-5  Z102244                   1
# 0-483-86369-6  YS-BB84                   1
# 0-490-60642-3  C794645                   1
# 0-527-63722-X  YS-BB74                   1
# 0-551-70009-2  BOT-001                   1
# 0-589-97501-3  PJ-909                    1
# 0-659-12918-3  BOT-301                   1
# 0-682-18222-2  YS-BB84                   1
# 0-698-58325-6  BOT-001                   1
# 0-7055-6975-6  YS-BB84                   1
# 0-7070-9686-3  PJ-909                    1
# 0-7570-5849-3  Proxxon Micromot MF 70    1
# 0-7742-3975-1  C794645                   1
# 0-7804-2562-6  YS-BB84                   1
# 0-8126-9848-7  BOT-001v2                 1
# 0-85198-360-X  C794645                   1
# 0-89198-495-X  A324404                   1
# 0-904698-44-0  C794645                   1
# 0-928644-69-3  B230494                   1
# 0-9655297-1-1  JS-182                    1
# 0-9776520-8-4  B230494                   1
# 1-01-055431-X  Quadro® Grind F10         1
# 1-02-051164-8  JS-182                    1
# 1-04-833845-2  Z102244                   1
# 1-100-62167-9  Proxxon Micromot MF 70    1
# 1-108-16741-1  BOT-001v2                 1
# 1-130-92790-3  YS-BB84                   1
# 1-135-44160-X  BTl9                      1
# 1-136-78176-5  BTl9                      1
# 1-153-45182-4  JS-182                    1
# 1-165-91623-1  Quadro® Grind F10         1
# 1-180-46921-6  C794645                   1
# 1-189-21228-5  BOT-301                   1
# 1-225-88957-X  Proxxon Micromot MF 70    1
# 1-284-46991-3  YS-BB74                   1
# 1-323-50723-X  BOT-001v2                 1
# 1-393-84813-3  C794645                   1
# 1-4141-7434-9  JS-182                    1
# 1-5479-4382-3  PJ-909                    1
# 1-57577-480-1  A324404                   1
# 1-68164-517-3  AM-953                    1
# 1-68565-420-7  Proxxon Micromot MF 70    1
# 1-69369-100-0  YS-BB84                   1
# 1-7391782-4-6  YS-BB74                   1
# 1-75070-515-X  Z102244                   1
# 1-79059-259-3  YS-BB74                   1
# 1-81657-661-1  BOT-001                   1
# 1-82233-397-0  JS-182                    1
# 1-82625-416-1  BOT-001                   1
# 1-874484-95-3  Quadro® Grind F10         1
# 1-913574-46-6  B230494                   1
# 1-922557-26-9  JS-182                    1
# 1-925366-36-7  C794645                   1
# 1-942462-98-0  JS-182                    1
# Name: model, dtype: int64

# %%
# different eq_id has different models associated to it, so there's no way to infer the id

#dropping null values
df_equip_lu.dropna(inplace=True)

#testing the amount of values (it should equals to 69 now)
df_equip_lu.info()

#doing that, we are losing 13,75% of data, which is pretty high.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 0 to 79
# Data columns (total 2 columns):
# eq_id    69 non-null object
# model    69 non-null object
# dtypes: object(2)
# memory usage: 1.6+ KB

# %% [markdown]
# #### Machine Transaction file

# %%
df_mach_tran.isnull().sum()
# Out:
# eq_id               87
# operation            0
# operator             0
# transaction_date     0
# dtype: int64

# %%
df_mach_tran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 0 to 24999
# Data columns (total 4 columns):
# eq_id               24913 non-null object
# operation           25000 non-null object
# operator            25000 non-null object
# transaction_date    25000 non-null object
# dtypes: object(4)
# memory usage: 976.6+ KB

# %%
#dropping null values
df_mach_tran.dropna(inplace=True)

#testing the amount of values (it should equals to 24913 now)
df_mach_tran.info()

#doing that, we are losing 0.35% of data, which is ok.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24913 entries, 0 to 24999
# Data columns (total 4 columns):
# eq_id               24913 non-null object
# operation           24913 non-null object
# operator            24913 non-null object
# transaction_date    24913 non-null object
# dtypes: object(4)
# memory usage: 973.2+ KB

# %%
#Question 3

df_timesheets.groupby('cost_per_hour')['person_id'].nunique().to_frame()
# Out:
#                person_id
# cost_per_hour
# 100                  381
# 200                  238
# 300                  131
# 600                  126
# 1000                 124

# %%
df_equip_lu.head()
# Out:
#            eq_id      model
# 0  0-698-58325-6    BOT-001
# 1  1-81657-661-1    BOT-001
# 2  0-236-67768-3       BTl9
# 4  1-108-16741-1  BOT-001v2
# 5  1-323-50723-X  BOT-001v2

# %%
#Question 4

df_equip_lu.model.value_counts()
# Out:
# C794645                   8
# JS-182                    7
# YS-BB84                   6
# YS-BB74                   5
# BOT-001                   5
# AM-953                    4
# A324404                   4
# BTl9                      4
# PJ-909                    4
# BOT-301                   4
# Proxxon Micromot MF 70    4
# B230494                   3
# Z102244                   3
# BOT-001v2                 3
# Quadro® Grind F10         3
# CP-144                    2
# Name: model, dtype: int64

# %%
df_timesheets.head()
# Out:
#   clock_off_date_time  clock_on_date_time  cost_per_hour   fname    lname  \
# 0 2017-05-01 14:50:03 2017-05-01 10:09:47            300  Adrian    Giles
# 1 2017-05-23 15:43:54 2017-05-23 12:00:53            300  George  Howells
# 2 2017-08-14 10:20:23 2017-08-14 10:18:53            200     Jay    Evans
# 3 2017-02-23 12:46:30 2017-02-23 10:11:21            300   Shaun  O'Neill
# 4 2017-05-04 16:38:50 2017-05-04 15:49:58            100  Pamela    Price
#
#    person_id
# 0  ZZ134689T
# 1  ZZ699213T
# 2  ZZ186312T
# 3  ZZ285185T
# 4  ZZ322544T

# %%
#Question 5

df_aux = df_timesheets.copy()

df_aux = df_aux[df_aux.cost_per_hour < 300]
#validating the statement above
df_aux.cost_per_hour.value_counts()

df_aux['clock_diff'] = df_aux.clock_off_date_time - df_aux.clock_on_date_time
df_aux['clock_on_onlyTime'] = df_aux.clock_on_date_time.apply(lambda x: str(x).split(" ")[1])
df_aux.clock_on_onlyTime = df_aux.clock_on_onlyTime.apply(lambda x: datetime.strptime(x, '%H:%M:%S'))
df_aux['time_agg_sec'] = df_aux.clock_on_onlyTime.apply(lambda x: int(x.hour*3600 + x.minute*60 + x.second))
# df_aux.head()
# df_aux.info()
df_aux.time_agg_sec.mean()
# Out:
# 42674.741111829346

# %%
df_mach_tran.head()
# Out:
#            eq_id                                          operation  \
# 0  0-341-31995-3  {'activity': '3d_printing', 'unit': 'kg', 'vol...
# 1  1-874484-95-3  {'activity': 'formulation', 'unit': 'ml', 'vol...
# 2  1-130-92790-3  {'activity': 'carbonizing', 'unit': 'g', 'volu...
# 3  1-79059-259-3  {'activity': 'painting', 'unit': 'ml', 'volume...
# 4  0-7570-5849-3  {'activity': '3d_printing', 'unit': 'kg', 'vol...
#
#     operator transaction_date
# 0  jgeorg473       01.01.2017
# 1  jpeter263       01.01.2017
# 2  gholde135       01.01.2017
# 3  ghardy464       01.01.2017
# 4  gholde135       01.01.2017

# %%
#Question 6

df_mach_tran['_3d_printer_flag_true'] = df_mach_tran.operation.apply(lambda x: True if '3d_printing' in x['activity'] else False)
df_aux = df_mach_tran.copy()

df_aux = df_aux[df_aux._3d_printer_flag_true]
df_joined = df_aux.merge(df_equip_lu, how='inner', on='eq_id')

df_joined.model.unique()
# Out:
# array(['Proxxon Micromot MF 70', 'YS-BB84', 'AM-953', 'JS-182', 'YS-BB74',
#        'B230494', 'BTl9', 'A324404', 'Z102244', 'Quadro® Grind F10',
#        'PJ-909', 'C794645', 'BOT-301', 'BOT-001v2', 'CP-144', 'BOT-001'], dtype=object)
